# %% [markdown]
# # Fetch songs of EG
# This notebook was used to retrieve the texts for the EG songs.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import pyarrow as pa
import pyarrow.parquet as pq

BASE_URL = "https://www.evangeliums.net/lieder"
SONG_LIST_URL = f"{BASE_URL}/liederbuch_evangelisches_gesangbuch.html"

# %%
def get_song_links():
    response = requests.get(SONG_LIST_URL)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")
    
    songs = []
    # Find all links in the song list
    for link in soup.select('table a'):
        title = link.text.strip()
        href = link.get('href')
        if "/lieder" in href:
            continue
        if href and title:
            full_url = BASE_URL + '/' + href
            songs.append({"title": title, "url": full_url})
    return songs
    
def get_song_text(url):
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    main = soup.find('main')
    print(f"found main")
    if not main:
        return None

    # Step 1: First <div> inside <main>
    divs = main.find_all('div', 'card-body')
    print(f"found {len(divs)} divs")
    if len(divs) < 1:
        return None
    song_text_div = divs[-1]

    print(f"found classes: {song_text_div.get('class', [])}")
    if not song_text_div or 'card-body' not in song_text_div.get('class', []):
        return None

    # Clean up: Remove all inner <div> elements inside the song_text_div
    for inner_div in song_text_div.find_all('div'):
        inner_div.decompose()

    # Extract all <p> tags
    verses = [
        p.get_text().replace("<br>", " | ").replace("\r\n", " | ")
        for p in song_text_div.find_all('p')
        if p.get_text(strip=True)
    ]

    # Join verses with "|"
    song_text = " | ".join(verses)
    return song_text

# %%
songs = get_song_links()
print(f"Found {len(songs)} songs.")
# Out:
# Found 536 songs.

# %% [markdown]
# ### Try out function `get_song_text`

# %%
song = songs[0]
get_song_text(song['url'])
# Out:
# found main
# found 3 divs
# found classes: ['card-body']
# "1)  Macht hoch die Tür, die Tor macht weit; | es kommt der Herr der Herrlichkeit, | ein König aller Königreich, | ein Heiland aller Welt zugleich, | der Heil und Leben mit sich bringt; | derhalben jauchzt, mit Freuden singt: | Gelobet sei mein Gott, | mein Schöpfer reich von Rat. | 2)  Er ist gerecht, ein Helfer wert; | Sanftmütigkeit ist sein Gefährt, | sein Königskron ist Heiligkeit, | sein Zepter ist Barmherzigkeit; | all unsre Not zum End er bringt, | derhalben jauchzt, mit Freuden singt: | Gelobet sei mein Gott, | mein Heiland groß von Tat. | 3)  O wohl dem Land, o wohl der Stadt, | so diesen König bei sich hat. | Wohl allen Herzen insgemein, | da dieser König ziehet ein. | Er ist die rechte Freudensonn, | bringt mit sich lauter Freud und Wonn. | Gelobet sei mein Gott, | mein Tröster früh und spat. | 4)  Macht hoch die Tür, die Tor macht weit, | eu'r Herz zum Tempel zubereit'. | Die Zweiglein der Gottseligkeit | steckt auf mit Andacht, Lust und Freud; | so kommt der König auch zu euch, | ja, Heil und Leben mit zugleich. | Gelobet sei mein Gott, | voll Rat, voll Tat, voll Gnad. | 5)  Komm, o mein Heiland Jesu Christ, | meins Herzens Tür dir offen ist. | Ach zieh mit deiner Gnade ein; | dein Freundlichkeit auch uns erschein. | Dein Heilger Geist uns führ und leit | den Weg zur ewgen Seligkeit. | Dem Namen dein, o Herr, | sei ewig Preis und Ehr."

# %% [markdown]
# ### Retrieve all song texts

# %%
songs = get_song_links()
print(f"Found {len(songs)} songs.")

data = []
for idx, song in enumerate(songs):
    print(f"Fetching ({idx + 1}/{len(songs)}): {song['title']}")
    try:
        text = get_song_text(song['url'])
        if text:
            data.append({
                "title": song['title'],
                "book": "EG",
                "number": idx+536,
                "lyrics": text
            })
        else:
            print(f"Warning: No text found for {song['title']}")
    except Exception as e:
            print(f"Error fetching {song['title']}: {e}")
    
    # Be polite to the server
    time.sleep(0.5)

df = pd.DataFrame(data)
print(f"Saving {len(df)} songs to 'evangelisches_gesangbuch_wu.parquet'...")

df.to_parquet("evangelisches_gesangbuch.parquet", engine="pyarrow", index=False)
# Out:
# Found 148 songs.
# Fetching (1/148): Auf auf ihr Christen alle
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (2/148): Sieh, dein König kommt zu dir
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (3/148): Der Tag, der ist so freudenreich
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (4/148): Sieh nicht an, was du selber bist
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (5/148): Stern über Bethlehem
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Stern über Bethlehem
# Fetching (6/148): Von guten Mächten wunderbar geborgen
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (7/148): Bleib bei uns, wenn der Tag entweicht
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Bleib bei uns, wenn der Tag entweicht
# Fetching (8/148): Geh unter der Gnade (Alte Stunden, alte Tage)
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Geh unter der Gnade (Alte Stunden, alte Tage)
# Fetching (9/148): Wie schön leuchtet der Morgenstern
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (10/148): Ach mein Herr Jesu
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (11/148): Eines wünsch ich mir vor allem andern
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (12/148): Christen und Heiden (Menschen gehen zu Gott in ihrer Not)
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (13/148): Kreuz, auf das ich schaue
# found main
# found 2 divs
# found classes: ['card-body']
# Warning: No text found for Kreuz, auf das ich schaue
# Fetching (14/148): Christus ist auferstanden (Kanon)
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (15/148): Die Sonne geht auf
# found main
# found 2 divs
# found classes: ['card-body']
# Warning: No text found for Die Sonne geht auf
# Fetching (16/148): Wo einer dem andern neu vertraut (Da kannst du Osterspuren finden)
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Wo einer dem andern neu vertraut (Da kannst du Osterspuren finden)
# Fetching (17/148): Auf diesen Tag bedenken wir
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (18/148): Gottes Stimme lasst uns sein (Kanon)
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (19/148): Der Geist des Herrn erfüllt das All
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Der Geist des Herrn erfüllt das All
# Fetching (20/148): Licht der Liebe (Ein Licht geht uns auf)
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Licht der Liebe (Ein Licht geht uns auf)
# Fetching (21/148): Der Geist von Gott weht wie der Wind
# found main
# found 2 divs
# found classes: ['card-body']
# Warning: No text found for Der Geist von Gott weht wie der Wind
# Fetching (22/148): Gott Vater Herr wir danken dir
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (23/148): Des Menschen Sohn wird kommen
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (24/148): Alles ist eitel, du aber bleibst (Kanon)
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (25/148): Jesu, Seelenfreund der Deinen
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (26/148): Treuer Heiland, wir sind hier
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (27/148): Jesu, Jesu, Brunn des Lebens
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (28/148): Der Herr segne dich und behüte dich (Amen, Amen, Amen)
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Der Herr segne dich und behüte dich (Amen, Amen, Amen)
# Fetching (29/148): Segne uns, o Herr! Lass leuchten dein Angesicht
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (30/148): Herr, wir bitten: Komm und segne uns
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Herr, wir bitten: Komm und segne uns
# Fetching (31/148): Gottes Ruhetag
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (32/148): Wieder kommen wir zusammen
# found main
# found 2 divs
# found classes: ['card-body']
# Warning: No text found for Wieder kommen wir zusammen
# Fetching (33/148): Wo zwei oder drei versammelt sind (Kanon)
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (34/148): Dass Erde und Himmel dir blühen (Kanon)
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (35/148): Die Gnade unsers Herrn Jesu Christi
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (36/148): Ubi caritas et amor
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (37/148): Gloria, Gloria, in excelsis Deo (Kanon)
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (38/148): Magnificat anima mea Dominum (Kanon)
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (39/148): Nada te turbe (Nichts soll dich ängsten)
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (40/148): Komm, göttliches Licht
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (41/148): Meine Hoffnung und meine Freude
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (42/148): Öffne meine Ohren, Heiliger Geist
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (43/148): Walte, walte nah und fern
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (130/148): Gelobt sei deine Treu, die jeden Morgen neu
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (131/148): Bescher uns Herr das täglich Brot
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (132/148): Die ihr bei Jesus bleibet
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (133/148): Du gabst der Welt das Leben (Kanon)
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (134/148): So ist die Woche nun geschlossen
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (135/148): Hirte deiner Schafe
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (136/148): Diesen Tag, Herr, leg ich zurück in deine Hände
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Diesen Tag, Herr, leg ich zurück in deine Hände
# Fetching (137/148): Heut war ein schöner Tag
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Heut war ein schöner Tag
# Fetching (138/148): Der Abend kommt
# found main
# found 2 divs
# found classes: ['card-body']
# Warning: No text found for Der Abend kommt
# Fetching (139/148): Wer wohlauf ist und gesund
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (140/148): Das walte Gott, der helfen kann
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (141/148): Geh aus, mein Herz und suche Freud
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (142/148): Die Ernt ist da es winkt der Halm
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (143/148): Auferstehn, ja auferstehn wirst du
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (144/148): Du kamst, du gingst mit leiser Spur
# found main
# found 2 divs
# found classes: ['card-body']
# Fetching (145/148): Brich herein, süßer Schein
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (146/148): Wir sind nur Gast auf Erden
# found main
# found 3 divs
# found classes: ['card-body']
# Fetching (147/148): Wir sind mitten im Leben zum Sterben bestimmt
# found main
# found 3 divs
# found classes: ['card-body']
# Warning: No text found for Wir sind mitten im Leben zum Sterben bestimmt
# Fetching (148/148): Jesus Christus, gestern und heute (Kanon)
# found main
# found 3 divs
# found classes: ['card-body']
# Saving 533 songs to 'evangelisches_gesangbuch_wu.parquet'...

# %%
# restart the loop with this SONG_LIST_URL to retrieve the songs for Regionalteil Württemberg
SONG_LIST_URL = f"{BASE_URL}/liederbuch_evangelisches_gesangbuch_regionalteil_wuerttemberg.html"

# %%
pd.read_parquet("evangelisches_gesangbuch.parquet")
# Out:
#                                          title book  number  \
# 0                           Macht hoch die Tür   EG       1
# 1        Er ist die rechte Freudensonn (Kanon)   EG       2
# 2           Gott, heilger Schöpfer aller Stern   EG       3
# 3                 Nun komm, der Heiden Heiland   EG       4
# 4                       Gottes Sohn ist kommen   EG       5
# ..                                         ...  ...     ...
# 528         Auferstehn, ja auferstehn wirst du   EG     678
# 529        Du kamst, du gingst mit leiser Spur   EG     679
# 530                 Brich herein, süßer Schein   EG     680
# 531                Wir sind nur Gast auf Erden   EG     681
# 532  Jesus Christus, gestern und heute (Kanon)   EG     683
#
#                                                 lyrics
# 0    1)  Macht hoch die Tür, die Tor macht weit; | ...
# 1    1)  Er ist die rechte Freudensonn, | bringt mi...
# 2    1)  Gott, heil'ger Schöpfer aller Stern, | erl...
# 3    1) Nun komm der Heiden Heiland, | der Jungfrau...
# 4    1)  Gottes Sohn ist kommen | uns allen zu From...
# ..                                                 ...
# 528  1) Auferstehn, ja auferstehn wirst du, | mein ...
# 529  Du kamst, du gingst mit leiser Spur, | ein flü...
# 530  1) Brich herein, süßer Schein selger Ewigkeit!...
# 531  1) Wir sind nur Gast auf Erden | und wandern o...
# 532  Jesus Christus, gestern und heute | und dersel...
#
# [533 rows x 4 columns]

# %%
# merge existing songs database (FJ songs) with EG songs
df0 = pd.read_parquet("songs.parquet")
df1 = pd.read_parquet("evangelisches_gesangbuch.parquet")
df2 = pd.concat([df0, df1], axis=0)
df2.to_parquet("songs_with_eg.parquet")
